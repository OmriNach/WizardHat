# %%
import ble2lsl
from ble2lsl.devices import ganglion

# %%
streamer = ble2lsl.Streamer(ganglion)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/omrinachmani/dev/envs/merlin/lib/python3.6/site-packages/serial/serialposix.py", line 265, in open
#     self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
# OSError: [Errno 24] Too many open files: '/dev/cu.usbmodem1'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/omrinachmani/dev/envs/merlin/lib/python3.6/site-packages/pygatt/backends/bgapi/bgapi.py", line 159, in _open_serial_port
#     timeout=0.25)
#   File "/Users/omrinachmani/dev/envs/merlin/lib/python3.6/site-packages/serial/serialutil.py", line 240, in __init__
#     self.open()
# ...

# %%
from wizardhat import acquire, plot

# %%
receiver = acquire.Receiver()
plot.Lines(receiver.buffers['EEG'])
# Out:
# Using source with ID Muse-7039-00:55:DA:B3:70:39
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-d69aa4bf1ed5> in <module>
#       1 receiver = acquire.Receiver()
# ----> 2 plot.Lines(receiver.buffers['EEG'])
#
# ~/dev/WizardHat/wizardhat/plot/plot.py in __init__(self, buffer, n_samples, palette, bgcolor, **kwargs)
#     113
#     114         if self.autostart:
# --> 115             self.run_server()
#     116
#     117     def _set_layout(self):
#
# ~/dev/WizardHat/wizardhat/plot/plot.py in run_server(self)
#      62         self.server.start()
#      63         self.server.io_loop.add_callback(self.server.show, '/')
# ---> 64         self.server.io_loop.start()
#      65
#      66     def _app_manager(self, curdoc):
#
# ~/dev/envs/merlin/lib/python3.6/site-packages/tornado/platform/asyncio.py in start(self)
#     130             self._setup_logging()
# ...
